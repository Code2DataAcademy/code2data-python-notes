# %% [markdown]
# Basic Operations

# %%
3+4 #addition
# Out:
# 7

# %%
4-5
# Out:
# -1

# %%
3*4 #multiplication
# Out:
# 12

# %%
3**4 #power
# Out:
# 81

# %%
42//2
# Out:
# 21

# %%
-42/2
# Out:
# -21.0

# %%
-45//2
# Out:
# -23

# %%
56.7/2
# Out:
# 28.35

# %%
56.7//2
# Out:
# 28.0

# %%
-78.9/3
# Out:
# -26.3

# %%
-78.9//3
# Out:
# -27.0

# %%
type(-90)
# Out:
# int

# %%
type(-90.0)
# Out:
# float

# %%
type("hello")
# Out:
# str

# %%
"hello "+"2" #concatenating
# Out:
# 'hello 2'

# %%
apple=2 #variable=value
print(apple) #value
# Out:
# 2

# %%
apple=4
print(apple)
# Out:
# 4

# %%
apple*apple
# Out:
# 16

# %%
apple*3
# Out:
# 12

# %%
"telephone"+"telephone"+"telephone"
# Out:
# 'telephonetelephonetelephone'

# %%
"telephone"*3
# Out:
# 'telephonetelephonetelephone'

# %%
a=1
b=3
print(a+b)
# Out:
# 4

# %%
a=1
b=3
a,b=b,a

# %%
print(a,b) #a=3;b=1
# Out:
# 3 1

# %%
i=a+1 #i=3+1=4
# Out:
# 4

# %%
i=4
i=i+1 #i+=1
print(i)
# Out:
# 5

# %%
i+=1
print(i)
# Out:
# 6

# %%
i=2
i*=3
print(i)
# Out:
# 6

# %%
50%2 #remainder
# Out:
# 0

# %%
57%2
# Out:
# 1

# %%
'hello'
# Out:
# 'hello'

# %%
"hello"
# Out:
# 'hello'

# %%
'''hello'''
# Out:
# 'hello'

# %%
"Lucy's car is red"
# Out:
# "Lucy's car is red"

# %%
'Lucy\'s car is red'
# Out:
# "Lucy's car is red"

# %%
a="Hello!"
a[0] #0th index=1st char
# Out:
# 'H'

# %%
a[2]
# Out:
# 'l'

# %%
a[-1] #-1=last;-2=2nd from the end
# Out:
# '!'

# %%
a[-2]
# Out:
# 'o'

# %%
a[-3]
# Out:
# 'l'

# %%
#[start:stop:jump]
#a="Hello!"
a[1:3:1]
# Out:
# 'el'

# %%
a[1:4]
# Out:
# 'ell'

# %%
a[3:5]
# Out:
# 'lo'

# %%
a="Hello!"
a[0:6:3]
# Out:
# 'Hl'

# %%
a[:3:1]
# Out:
# 'Hel'

# %%
a[:]
# Out:
# 'Hello!'

# %%
a[::-1]
# Out:
# '!olleH'

# %%
a="Hello!"
a[2]="m"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 2
#       1 a="Hello!"
# ----> 2 a[2]="m"
#
# TypeError: 'str' object does not support item assignment

# %%
-46.2/1
# Out:
# -46.2

# %%
len(a)
# Out:
# 6
